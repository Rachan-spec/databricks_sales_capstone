# %%
# Read source CSV

df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Workspace/Users/rachangowdarachu@gmail.com/databricks_sales_capstone/data/sales_source_1500.csv")

# Write Bronze table

df.write.mode("overwrite").saveAsTable(
    "workspace.default.capstone_bronze_sales"
)

print("Bronze table created successfully")

# %%
# %sql
SELECT COUNT(*) 
FROM workspace.default.capstone_bronze_sales;
